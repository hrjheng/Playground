# %%
from pytrends.request import TrendReq
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as web
from datetime import datetime

sns.set()

# %%
pytrend = TrendReq(hl='en-US', tz=360, retries=10000, backoff_factor=0.5)

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
# kw_list=['柯文哲','蔡英文','韓國瑜','郭台銘','假新聞']
kw_list=['國民黨','民進黨','台灣民眾黨','親民黨','時代力量']
# pytrend.build_payload(kw_list, timeframe = 'all')
# pytrend.build_payload(kw_list, timeframe = '2010-10-01 2019-01-01')
pytrend.build_payload(kw_list, timeframe = '2018-08-01 2019-12-31')

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
# interest_over_time_df = pytrend.get_historical_interest(kw_list, year_start=2019, month_start=1, day_start=1, year_end=2019, month_end=12, day_end=31, cat=0, geo='', gprop='', sleep=0)
# col_names = ['Wen-Je Ko','Ing-Wen Tsai','Kuo-yu Han','Terry Gou','fake news']
col_names = ['KMT','DPP','TPP','PFP','NPP']
for iname in range(len(col_names)):
    interest_over_time_df.rename(columns={interest_over_time_df.columns[iname]: col_names[iname]}, inplace=True)
        

interest_over_time_df.drop('isPartial', axis=1, inplace=True)
interest_over_time_df.head()
# Out:
#             KMT  DPP  TPP  PFP  NPP
# date
# 2018-08-05    8    7    0    0    1
# 2018-08-12    7    7    0    0    2
# 2018-08-19    8    7    0    0    2
# 2018-08-26   10    5    0    0    1
# 2018-09-02    6    6    0    0    1

# %%
related_queries_dict = pytrend.related_queries()
related_queries_dict['國民黨']
# Out:
# {'top':               query  value
#  0          不 分區 國民黨    100
#  1       國民黨 不 分區 名單     73
#  2            中國 國民黨     64
#  3        國民黨 初 選 結果     56
#  4            國民黨 總統     55
#  5              韓國 瑜     53
#  6          韓國 瑜 國民黨     52
#  7      國民黨 不 分區 立 委     41
#  8            台灣 國民黨     41
#  9          不 分區 立 委     41
#  10       國民黨 立 委 名單     35
#  11       國民黨 總統 初 選     33
#  12          國民黨 ptt     31
#  13           國民黨 主席     28
#  14         國民黨 候選 人     28
#  15  國民黨 立 委 不 分區 名單     26
#  16           國民黨 英文     21
#  17          郭台銘 國民黨     18
#  18      國民黨 政見 發表 會     18
#  19              郭台銘     17
#  20               新聞     15
#  21          政見 發表 會     15
#  22       高雄 國民黨 黨 部     15
#  23              共產黨     14
#  24       國民黨 立 委 提名     14, 'rising':                    query  value
#  0             國民黨 初 選 時間  79550
#  1             國民黨 民 調 時間  59400
#  2         國民黨 初 選 民 調 時間  51250
#  3         國民黨 總統 初 選 民 調  38700
#  4        國民黨 不 分區 立 委 提名  34600
#  5              國民黨 和平 協議  32100
#  6       國民黨 不 分區 名單 2020  29400
#  7         國民黨 立 委 初 選 名單  28550
#  8                  和平 協議  27300
#  9   國民黨 不 分區 立 委 名單 2020  26650
#  10              蕭 夫人 國民黨  25800
#  11        國民黨 立 委 初 選 結果  25800
#  12       國民黨 初 選 政見 發表 會  24100
#  13                  蕭 夫人  23650
#  14              國民黨 吉祥 物  23500
#  15               李正皓 國民黨  21950
#  16            國民黨 民 調 公司  20550
#  17            國民黨 31 大 老  20400
#  18              國民黨 撲克 牌  19900
#  19    國民黨 不 分區 立 委 提名 名單  19000
#  20         國民黨 總統 初 選 日期  18750
#  21        國民黨 初 選 民 調 公司  17700
#  22            國民黨 初 選 直播  17100
#  23            韓國 瑜 競選 總部  16950
#  24          103 年 國民黨 主席  16550}

# %%
interest_over_time_df.plot(figsize=(9,5))
plt.tight_layout()

# %%
### one simple way to visualize correlation matrix from dataframe
corr = interest_over_time_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col1 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col0 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col0 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col1 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col4 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col1 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col2 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col3 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >KMT</th>        <th class="col_heading level0 col1" >DPP</th>        <th class="col_heading level0 col2" >TPP</th>        <th class="col_heading level0 col3" >PFP</th>        <th class="col_heading level0 col4" >NPP</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35level0_row0" class="row_heading level0 row0" >KMT</th>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col1" class="data row0 col1" >0.409034</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col2" class="data row0 col2" >0.00237179</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col3" class="data row0 col3" >0.354442</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row0_col4" class="data row0 col4" >0.317507</td>
#             </tr>
#             <tr>
#                         <th id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35level0_row1" class="row_heading level0 row1" >DPP</th>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col0" class="data row1 col0" >0.409034</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col2" class="data row1 col2" >-0.0235233</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col3" class="data row1 col3" >0.338131</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row1_col4" class="data row1 col4" >0.573256</td>
#             </tr>
#             <tr>
#                         <th id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35level0_row2" class="row_heading level0 row2" >TPP</th>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col0" class="data row2 col0" >0.00237179</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col1" class="data row2 col1" >-0.0235233</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col3" class="data row2 col3" >0.19927</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row2_col4" class="data row2 col4" >0.47828</td>
#             </tr>
#             <tr>
#                         <th id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35level0_row3" class="row_heading level0 row3" >PFP</th>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col0" class="data row3 col0" >0.354442</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col1" class="data row3 col1" >0.338131</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col2" class="data row3 col2" >0.19927</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row3_col4" class="data row3 col4" >0.417545</td>
#             </tr>
#             <tr>
#                         <th id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35level0_row4" class="row_heading level0 row4" >NPP</th>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col0" class="data row4 col0" >0.317507</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col1" class="data row4 col1" >0.573256</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col2" class="data row4 col2" >0.47828</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col3" class="data row4 col3" >0.417545</td>
#                         <td id="T_83be1478_24d5_11ea_ae77_9801a7dc4b35row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(figsize=(8, 7))
corr = interest_over_time_df.corr()
ax = sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={"size": 20},
            xticklabels=interest_over_time_df.columns,
            yticklabels=interest_over_time_df.columns,
            cmap="coolwarm_r",
            vmin=-1.0,
            vmax=1.0)
ax.set_xlabel('',fontsize=21)
ax.set_ylabel('', fontsize=21)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, horizontalalignment='right')

cbar = ax.collections[0].colorbar
# here set the labelsize by 20
cbar.ax.tick_params(labelsize=18)
cbar.ax.set_ylabel('Correlation',size=20)

plt.tight_layout()

# %%
kw_list=['鴻海','鴻海股價','富士康','郭台銘','股票']
# pytrend.build_payload(kw_list, timeframe = 'all')
# pytrend.build_payload(kw_list, timeframe = '2010-10-01 2019-01-01')
pytrend.build_payload(kw_list, timeframe = '2015-01-01 2019-12-31')

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
# interest_over_time_df = pytrend.get_historical_interest(kw_list, year_start=2019, month_start=1, day_start=1, year_end=2019, month_end=12, day_end=31, cat=0, geo='', gprop='', sleep=0)
col_names = ['Google search: Foxconn Technology Group','Google search: Foxconn Technology Group stock price','Google search: Foxconn','Google search: Terry Gou','Google search: Stock']
for iname in range(len(col_names)):
    interest_over_time_df.rename(columns={interest_over_time_df.columns[iname]: col_names[iname]}, inplace=True)
        

interest_over_time_df.drop('isPartial', axis=1, inplace=True)

(interest_over_time_df.style
     .background_gradient('Reds',subset='Google search: Foxconn Technology Group')
     .background_gradient('Reds',subset='Google search: Foxconn Technology Group stock price')
     .background_gradient('Reds',subset='Google search: Foxconn')
     .background_gradient('Reds',subset='Google search: Terry Gou')
     .background_gradient('Reds',subset='Google search: Stock')
     # .background_gradient('Greens', subset='Google search: Stock')
     .highlight_null()
)
# Out:
# <style  type="text/css" >
#     #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row0_col0 {
#             background-color:  #fee0d2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row0_col1 {
#             background-color:  #fedaca;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row0_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row0_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row0_col4 {
#             background-color:  #fc8b6b;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row1_col0 {
#             background-color:  #fee3d7;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row1_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row1_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row1_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row1_col4 {
#             background-color:  #fc9576;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row2_col0 {
#             background-color:  #fcb99f;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row2_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row2_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row2_col3 {
#             background-color:  #fee9df;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row2_col4 {
#             background-color:  #fc997a;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row3_col0 {
#             background-color:  #fedaca;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row3_col1 {
#             background-color:  #fedaca;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row3_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row3_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row3_col4 {
#             background-color:  #fc997a;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row4_col0 {
#             background-color:  #fee3d7;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row4_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row4_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row4_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row4_col4 {
#             background-color:  #fca98c;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row5_col0 {
#             background-color:  #fedaca;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row5_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row5_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row5_col4 {
#             background-color:  #fcad90;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row6_col0 {
#             background-color:  #fff2ec;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row6_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row6_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row6_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row6_col4 {
#             background-color:  #fee6da;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row7_col0 {
#             background-color:  #fee6da;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row7_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row7_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row7_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row7_col4 {
#             background-color:  #fcb89e;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row8_col0 {
#             background-color:  #fee0d2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row8_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row8_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row8_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row8_col4 {
#             background-color:  #fc9576;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row9_col0 {
#             background-color:  #fee0d2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row9_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row9_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row9_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row9_col4 {
#             background-color:  #fc8767;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row10_col0 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row10_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row10_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#             : ;
#         }    #T_96f8b7a6_2407_11ea_974f_9801a7dc4b35row10_col3 {
#             backgr

# %%
f, ax = plt.subplots(figsize=(12, 10))
corr = interest_over_time_df.corr()
ax = sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={"size": 20},
            xticklabels=interest_over_time_df.columns,
            yticklabels=interest_over_time_df.columns,
            cmap="coolwarm_r",
            vmin=-1.0,
            vmax=1.0)
ax.set_xlabel('',fontsize=21)
ax.set_ylabel('', fontsize=21)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
ax.set_xticklabels(ax.get_xticklabels(), rotation=270, horizontalalignment='right')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')

cbar = ax.collections[0].colorbar
# here set the labelsize by 20
cbar.ax.tick_params(labelsize=18)
cbar.ax.set_ylabel('Correlation',size=20)

plt.tight_layout()

# %%
start = datetime(2015, 1, 1)
df = web.DataReader('2317.TW', 'yahoo', start)
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-05  95.021698  94.047600  95.021698  94.372299  23308824.0  79.629990
# 2015-01-06  93.073601  91.450203  93.073601  91.450203  60587604.0  77.164368
# 2015-01-07  92.857101  91.233803  91.233803  92.207802  31148964.0  77.803619
# 2015-01-08  94.155800  92.748901  92.965401  94.047600  28348320.0  79.356010
# 2015-01-09  95.021698  93.614700  94.480499  93.614700  20894412.0  78.990738

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(111)

ax1.plot(interest_over_time_df.index, interest_over_time_df[interest_over_time_df.columns[0]], label='Google search: Foxconn Technology Group', linewidth=3)
ax1.plot(interest_over_time_df.index, interest_over_time_df[interest_over_time_df.columns[1]], label='Google search: Foxconn Technology Group stock price', linewidth=3)
ax1.plot(interest_over_time_df.index, interest_over_time_df[interest_over_time_df.columns[2]], label='Google search: Foxconn', linewidth=3)
ax1.plot(interest_over_time_df.index, interest_over_time_df[interest_over_time_df.columns[3]], label='Google search: Terry Guo', linewidth=3)
ax1.plot(interest_over_time_df.index, interest_over_time_df[interest_over_time_df.columns[4]], label='Google search: Stock', linewidth=3)
ax1.set_ylabel('Interest', fontsize=21)
ax1.tick_params(axis='x', labelsize=18)
ax1.tick_params(axis='y', labelsize=18)
# ax1.set_title('Company: '+company,fontsize = 32)

ax2 = ax1.twinx()
color='C5'
ax2.plot(df.index, df['Close'], label='Foxconn Technology Group stock price', linewidth=3, color=color,linestyle='--')
ax2.tick_params(axis='y', labelsize=18, labelcolor=color, colors=color)
ax2.set_ylabel('Stock price', fontsize=21, color=color)
ax2.spines['right'].set_color(color)

plt.grid(False)

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax2.legend(h1+h2, l1+l2, loc='best',fontsize='xx-large')

plt.tight_layout()
