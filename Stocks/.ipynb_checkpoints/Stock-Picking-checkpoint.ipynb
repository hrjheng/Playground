# %%
import pandas as pd
import pandas_datareader.data as web
import requests
from io import StringIO
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

import pickle

import pandas_profiling

import copy

sns.set()

# %% [markdown]
# ## References ##
# * [超簡單用python抓取每月營收](https://www.finlab.tw/%E8%B6%85%E7%B0%A1%E5%96%AE%E7%94%A8python%E6%8A%93%E5%8F%96%E6%AF%8F%E6%9C%88%E7%87%9F%E6%94%B6/)
# * [Python-簡單的月營收選股！](https://www.finlab.tw/Python-%E7%B0%A1%E5%96%AE%E7%94%A8%E6%9C%88%E7%87%9F%E6%94%B6%E9%81%B8%E8%82%A1%EF%BC%81/)
# * [Python 簡單選股和回測](https://www.finlab.tw/Python-%E7%B0%A1%E5%96%AE%E9%81%B8%E8%82%A1%E5%92%8C%E5%9B%9E%E6%B8%AC/)
# * [絕無僅有的超強指標！](https://www.finlab.tw/%E7%B5%95%E7%84%A1%E5%83%85%E6%9C%89%E7%9A%84%E8%B6%85%E5%BC%B7%E6%8C%87%E6%A8%99%EF%BC%81/)
# * [優分析](https://forum.uanalyze.com.tw/forum)

# %% [markdown]
# ## 取得近7年月盈利資料 & 結合月營收資訊 ##

# %%
# with open('Monthly-revenue-201412to201911.pickle', 'rb') as file:
with open('Monthly-revenue-201211to201911.pickle', 'rb') as file:
    data = pickle.load(file)
    
file.close()

for k in data.keys():
    data[k].index = data[k]['公司代號']
    
df = pd.DataFrame({k:df['當月營收'] for k, df in data.items()}).transpose()
df.index = pd.to_datetime(df.index)
df = df.sort_index()
df.head()
# Out:
#                  1101       1102      1103      1104      1108      1109  \
# 2012-11-01  2016287.0  1116753.0   94668.0  318461.0  309670.0  142214.0
# 2012-12-01  1974285.0  1066478.0  112508.0  307905.0  328224.0  146031.0
# 2013-01-01  9134465.0  6018213.0  288455.0  486481.0  481802.0  383780.0
# 2013-02-01  5540346.0  2552357.0  166638.0  299860.0  276936.0  149301.0
# 2013-03-01  9457971.0  5428755.0  286007.0  461732.0  444917.0  382253.0
#
#                 1110       1201      1203       1210  ...       9940  \
# 2012-11-01  171133.0  1199157.0  146586.0  2040013.0  ...   626469.0
# 2012-12-01  165428.0  1209287.0  169246.0  2181625.0  ...   855589.0
# 2013-01-01  179660.0  2293196.0  540783.0  7783821.0  ...   794914.0
# 2013-02-01  113585.0  2065554.0  505506.0  5933139.0  ...   549536.0
# 2013-03-01  166981.0  2477894.0  539328.0  7306534.0  ...  1210549.0
#
#                  9941      9942      9943      9944       9945      9946  \
# 2012-11-01   220887.0  138546.0  216083.0   22969.0   435777.0  303870.0
# 2012-12-01   225060.0  141937.0  263918.0   23608.0   586761.0  175748.0
# 2013-01-01  1257587.0  208732.0  286671.0  297938.0  1288950.0  519794.0
# 2013-02-01  1035595.0  140150.0  344812.0  253338.0   991617.0  177028.0
# 2013-03-01  1220143.0  211044.0  246314.0  352136.0  1257334.0  771107.0
#
#                 9955      9958    全部國內上市公司合計
# 2012-11-01  426869.0  415460.0           NaN
# 2012-12-01  296301.0  421821.0           NaN
# 2013-01-01  394489.0  198944.0  2.237051e+09
# 2013-02-01  383183.0  166364.0  1.708683e+09
# 2013-03-01  428478.0  351222.0  2.089220e+09
#
# [5 rows x 896 columns]

# %% [markdown]
# ### 創造一個新的 dataframe 存取各上市公司基本資訊 ###

# %%
columns = ['Nmonthgrowth_revenue_1y','Nmonthgrowth_revenue_2y']
df_basic = pd.DataFrame(index=data['2019-11-01']['公司代號'], columns=columns)
df_basic = df_basic.fillna(0) # with 0s rather than NaNs
df_basic.index.name = 'Stock_symbol'
# df_basic.head()
# df_basic.index

avg = 6
list_Nmonthgrowth_1y = []
list_Nmonthgrowth_2y = []
list_1y_greater6m = []
list_2y_greater15m = []
for i in df_basic.index:
    method_growth = df[i].rolling(avg).mean()
    method_growth_1y = (method_growth > method_growth.shift()).iloc[-12:].sum() #計算過去一年內連續幾個月月營收皆為成長 
    method_growth_2y = (method_growth > method_growth.shift()).iloc[-24:].sum() #計算過去兩年內連續幾個月月營收皆為成長 
    list_Nmonthgrowth_1y.append(method_growth_1y)
    list_Nmonthgrowth_2y.append(method_growth_2y)
    list_1y_greater6m.append((method_growth_1y>6))
    list_2y_greater15m.append((method_growth_2y>15))
    
df_basic['Nmonthgrowth_revenue_1y'] = list_Nmonthgrowth_1y
df_basic['Nmonthgrowth_revenue_2y'] = list_Nmonthgrowth_2y
df_basic['Nmonthgrowth_revenue_1ygreater6m'] = list_1y_greater6m
df_basic['Nmonthgrowth_revenue_2ygreater15m'] = list_2y_greater15m

df_basic.drop(['全部國內上市公司合計'], inplace=True)
df_basic.head()
# Out:
#               Nmonthgrowth_revenue_1y  Nmonthgrowth_revenue_2y  \
# Stock_symbol
# 1101                                6                       16
# 1102                                6                       16
# 1103                                6                       12
# 1104                                6                       13
# 1108                                8                       15
#
#               Nmonthgrowth_revenue_1ygreater6m  \
# Stock_symbol
# 1101                                     False
# 1102                                     False
# 1103                                     False
# 1104                                     False
# 1108                                      True
#
#               Nmonthgrowth_revenue_2ygreater15m
# Stock_symbol
# 1101                                       True
# 1102                                       True
# 1103                                      False
# 1104                                      False
# 1108                                      False

# %% [markdown]
# ## 取得近7年股價波動率 ##

# %%
with open('Volatility-7y.pickle', 'rb') as file:
    list_volatility = pickle.load(file)
    
file.close()

df_basic['volatility'] = list_volatility
df_basic.head()
# Out:
#               Nmonthgrowth_revenue_1y  Nmonthgrowth_revenue_2y  \
# Stock_symbol
# 1101                                6                       16
# 1102                                6                       16
# 1103                                6                       12
# 1104                                6                       13
# 1108                                8                       15
#
#               Nmonthgrowth_revenue_1ygreater6m  \
# Stock_symbol
# 1101                                     False
# 1102                                     False
# 1103                                     False
# 1104                                     False
# 1108                                      True
#
#               Nmonthgrowth_revenue_2ygreater15m  volatility
# Stock_symbol
# 1101                                       True    0.014522
# 1102                                       True    0.013559
# 1103                                      False    0.012836
# 1104                                      False    0.012523
# 1108                                      False    0.010666

# %% [markdown]
# ---
# ## 取得殖利率、本益比、股價淨值比等 ##
# * [只用一行程式碼分析數據!?（實用的 Python Package）](https://www.finlab.tw/one-line-info-dataframe/)
# * [台灣證券交易所：個股日本益比、殖利率及股價淨值比](https://www.twse.com.tw/zh/page/trading/exchange/BWIBBU_d.html)
# * [一分鐘看懂本益比 – 如何找出便宜的股票?](https://rich01.com/pe-ratio-basic/)

# %%
with open('Dividend_yield-200809to201911.pickle', 'rb') as file:
    data_dict = pickle.load(file)

data_div_yield = copy.deepcopy(data_dict)
data_PER = copy.deepcopy(data_dict)
data_PBR = copy.deepcopy(data_dict)


for k in data_dict.keys():
    data_div_yield[k].rename(columns={'證券代號': 'Stock_symbol', '證券名稱': 'Stock_name', '殖利率(%)': 'Dividend_yield',
                  '股利年度': 'Divident_year', '本益比': 'PER', '股價淨值比': 'PBR', '財報年/季': 'Report_year_quarter'},inplace=True)
    data_div_yield[k].index = data_div_yield[k]['Stock_symbol']
    
    data_PER[k].rename(columns={'證券代號': 'Stock_symbol', '證券名稱': 'Stock_name', '殖利率(%)': 'Dividend_yield',
                  '股利年度': 'Divident_year', '本益比': 'PER', '股價淨值比': 'PBR', '財報年/季': 'Report_year_quarter'},inplace=True)
    data_PER[k].index = data_PER[k]['Stock_symbol']
    
    data_PBR[k].rename(columns={'證券代號': 'Stock_symbol', '證券名稱': 'Stock_name', '殖利率(%)': 'Dividend_yield',
                  '股利年度': 'Divident_year', '本益比': 'PER', '股價淨值比': 'PBR', '財報年/季': 'Report_year_quarter'},inplace=True)
    data_PBR[k].index = data_PBR[k]['Stock_symbol']
    data_PBR[k]['PBR'] = pd.to_numeric(data_PBR[k]['PBR'], 'coerce')
    
df_div_yield = pd.DataFrame({k:df_div_yield['Dividend_yield'] for k, df_div_yield in data_div_yield.items()}).transpose()
df_div_yield.index = pd.to_datetime(df_div_yield.index)
df_div_yield = df_div_yield.sort_index()
    
df_PER = pd.DataFrame({k:df_PER['PER'] for k, df_PER in data_PER.items()}).transpose()
df_PER.index = pd.to_datetime(df_PER.index)
df_PER = df_PER.sort_index()

df_PBR = pd.DataFrame({k:df_PBR['PBR'] for k, df_PBR in data_PBR.items()}).transpose()
df_PBR.index = pd.to_datetime(df_PBR.index)
df_PBR = df_PBR.sort_index()


### 檢查 
# df_div_yield.tail()
# df_PER.tail()
df_PBR.tail()
# Out:
#             1101  1102  1103  1104  1108  1109  1110  1201  1203  1210  ...  \
# 2019-10-25  1.18  1.04  0.55  0.70  0.76  1.00  1.14  1.88  1.32  1.63  ...
# 2019-11-01  1.17  1.03  0.56  0.70  0.76  0.98  1.14  1.92  1.33  1.61  ...
# 2019-11-25  1.29  1.08  0.61  0.69  0.72  1.00  1.14  1.81  1.30  1.73  ...
# 2019-12-09  1.30  1.09  0.58  0.70  0.72  0.96  1.14  1.76  1.30  1.82  ...
# 2019-12-17  1.32  1.12  0.59  0.71  0.75  1.00  1.14  1.78  1.30  1.85  ...
#
#             9939  9940  9941  9942  9943  9944  9945  9946  9955  9958
# 2019-10-25  1.25  2.16  2.59  2.04  2.61  0.64  0.68  1.11  1.14  4.01
# 2019-11-01  1.24  2.14  2.56  2.04  2.59  0.64  0.68  1.09  1.12  4.08
# 2019-11-25  1.31  2.16  2.78  1.97  2.50  0.66  0.57  1.28  1.07  3.53
# 2019-12-09  1.32  2.14  2.69  1.97  2.53  0.66  0.56  1.28  1.09  3.43
# 2019-12-17  1.35  2.16  2.73  1.99  2.61  0.65  0.55  1.24  1.07  3.50
#
# [5 rows x 1009 columns]

# %% [markdown]
# ### 將殖利率及本益比存進新創的dataframe、做簡單的Boolean值###

# %%
avg = 18 # 每個月平均取3筆資料 => 半年期間約18筆資料

list_Dyield5_3y = []
list_Dyield5_3y_greater15 = []
list_Dyield5_2y_greater12 = []
list_Dyield5_1y_greater9 = []
list_Dyieldgrowth_p5y = []
list_Dyieldgrowth_1y = []
list_Dyieldgrowth_2y = []
list_Dyieldgrowth_3y = []
list_Dyieldgrowth_p5y_greater5 = []
list_Dyieldgrowth_1y_greater9 = []

list_PER15_3y = []
list_PER15_3y_greater15 = []
list_PERdrop_p5y = []
list_PERdrop_1y = []
list_PERdrop_2y = []
list_PERdrop_3y = []

for i in df_basic.index:
    if i=='6706':
        list_Dyield5_3y.append(0)
        list_PER15_3y.append(0)
        list_Dyieldgrowth_p5y.append(0)
        list_Dyieldgrowth_1y.append(0)
        list_Dyieldgrowth_2y.append(0)
        list_Dyieldgrowth_3y.append(0)
        list_Dyield5_3y_greater15.append(False)
        list_Dyield5_2y_greater12.append(False)
        list_Dyield5_1y_greater9.append(False)
        list_Dyieldgrowth_p5y_greater5.append(False)
        list_Dyieldgrowth_1y_greater9.append(False)
    
        list_PERdrop_p5y.append(0)
        list_PERdrop_1y.append(0)
        list_PERdrop_2y.append(0)
        list_PERdrop_3y.append(0)
        list_PER15_3y_greater15.append(False)
        
        continue
        
    method_Dyield = df_div_yield[i].rolling(avg).mean()
    method_PER = df_PER[i].rolling(avg).mean()
    
    list_Dyield5_3y.append(((method_Dyield>=5.).iloc[-108:].sum())/3) # 計算過去三年內有幾個月 殖利率>=5
    list_Dyield5_3y_greater15.append((((method_Dyield>=5.).iloc[-108:].sum())/3)>=15)
    list_Dyield5_2y_greater12.append((((method_Dyield>=5.).iloc[-72:].sum())/3)>=12)
    list_Dyield5_1y_greater9.append((((method_Dyield>=5.).iloc[-36:].sum())/3)>=9)
    
    list_PER15_3y.append(((method_PER<=15.).iloc[-108:].sum())/3) # 計算過去三年內有幾個月 PER(本益比)<=15
    list_PER15_3y_greater15.append((((method_PER<=15.).iloc[-108:].sum())/3)>=15)
    
    method_Dyieldgrowth_p5y = (method_Dyield > method_Dyield.shift()).iloc[-18:].sum() # 計算過去半年內有幾個月殖利率為成長
    method_Dyieldgrowth_1y = (method_Dyield > method_Dyield.shift()).iloc[-36:].sum() # 計算過去一年內
    method_Dyieldgrowth_2y = (method_Dyield > method_Dyield.shift()).iloc[-72:].sum() # 計算過去兩年內
    method_Dyieldgrowth_3y = (method_Dyield > method_Dyield.shift()).iloc[-108:].sum() # 計算過去三年內
    
    method_PERdrop_p5y = (method_PER < method_PER.shift()).iloc[-18:].sum() # 計算過去半年內 
    method_PERdrop_1y = (method_PER < method_PER.shift()).iloc[-36:].sum() # 計算過去一年內
    method_PERdrop_2y = (method_PER < method_PER.shift()).iloc[-72:].sum() # 計算過去兩年內
    method_PERdrop_3y = (method_PER < method_PER.shift()).iloc[-108:].sum() # 計算過去三年內
    
    list_Dyieldgrowth_p5y.append(method_Dyieldgrowth_p5y/3)
    list_Dyieldgrowth_1y.append(method_Dyieldgrowth_1y/3)
    list_Dyieldgrowth_2y.append(method_Dyieldgrowth_2y/3)
    list_Dyieldgrowth_3y.append(method_Dyieldgrowth_3y/3)
    list_Dyieldgrowth_p5y_greater5.append((method_Dyieldgrowth_p5y/3)>5.)
    list_Dyieldgrowth_1y_greater9.append((method_Dyieldgrowth_1y/3)>9.)
    
    list_PERdrop_p5y.append(method_PERdrop_p5y/3)
    list_PERdrop_1y.append(method_PERdrop_1y/3)
    list_PERdrop_2y.append(method_PERdrop_2y/3)
    list_PERdrop_3y.append(method_PERdrop_3y/3)
    
    
    
df_basic['Nmonth_Dyield5_3year'] = list_Dyield5_3y
df_basic['Nmonth_Dyield5_3year_greater15'] = list_Dyield5_3y_greater15
df_basic['Nmonth_Dyield5_2year_greater12'] = list_Dyield5_2y_greater12
df_basic['Nmonth_Dyield5_1year_greater9'] = list_Dyield5_1y_greater9
df_basic['Nmonthgrowth_Dyield_p5y'] = list_Dyieldgrowth_p5y
df_basic['Nmonthgrowth_Dyield_1y'] = list_Dyieldgrowth_1y
df_basic['Nmonthgrowth_Dyield_2y'] = list_Dyieldgrowth_2y
df_basic['Nmonthgrowth_Dyield_3y'] = list_Dyieldgrowth_3y
df_basic['Nmonthgrowth_Dyield_p5y_greater5'] = list_Dyieldgrowth_p5y_greater5
df_basic['Nmonthgrowth_Dyield_1y_greater9'] = list_Dyieldgrowth_1y_greater9

df_basic['Nmonth_PER15_3year'] = list_PER15_3y
df_basic['Nmonth_PER15_3year_greater15'] = list_PER15_3y_greater15
df_basic['Nmonthdrop_PER_p5y'] = list_PERdrop_p5y
df_basic['Nmonthdrop_PER_1y'] = list_PERdrop_1y
df_basic['Nmonthdrop_PER_2y'] = list_PERdrop_2y
df_basic['Nmonthdrop_PER_3y'] = list_PERdrop_3y

df_basic.head()
# Out:
#               Nmonthgrowth_revenue_1y  Nmonthgrowth_revenue_2y  \
# Stock_symbol
# 1101                                6                       16
# 1102                                6                       16
# 1103                                6                       12
# 1104                                6                       13
# 1108                                8                       15
#
#               Nmonthgrowth_revenue_1ygreater6m  \
# Stock_symbol
# 1101                                     False
# 1102                                     False
# 1103                                     False
# 1104                                     False
# 1108                                      True
#
#               Nmonthgrowth_revenue_2ygreater15m  volatility  \
# Stock_symbol
# 1101                                       True    0.014522
# 1102                                       True    0.013559
# 1103                                      False    0.012836
# 1104                                      False    0.012523
# 1108                                      False    0.010666
#
#               Nmonth_Dyield5_3year  Nmonth_Dyield5_3year_greater15  \
# Stock_symbol
# 1101                     15.666667                            True
# 1102                      8.000000                           False
# 1103                      5.000000                           False
# 1104                     28.666667                            True
# 1108                     22.333333                            True
#
#               Nmonth_Dyield5_2year_greater12  Nmonth_Dyield5_1year_greater9  \
# Stock_symbol
# 1101                                    True                           True
# 1102                                   False                          False
# 1103                                   False                          False
# 1104                                    True                           True
# 1108                                   False                          False
#
#               Nmonthgrowth_Dyield_p5y  ...  Nmonthgrowth_Dyield_2y  \
# Stock_symbol                           ...
# 1101                         5.333333  ...               19.000000
# 1102                         3.666667  ...               11.333333
# 1103                         4.000000  ...               18.000000
# 1104                         1.666667  ...               11.000000
# 1108                         0.000000  ...                6.333333
#
#               Nmonthgrowth_Dyield_3y  Nmonthgrowth_Dyield_p5y_greater5  \
# Stock_symbol
# 1101                       22.666667                              True
# 1102                       12.666667                             False
# 1103                       19.666667                             False
# 1104                       15.666667                             False
# 1108                       13.333333                             False
#
#               Nmonthgrowth_Dyield_1y_greater9  Nmonth_PER15_3year  \
# Stock_symbol
# 1101                                     True           10.333333
# 1102                                    False           10.666667
# 1103                                    False           11.333333
# 1104                                    False           36.000000
# 1108                                    False           12.666667
#
#               Nmonth_PER15_3year_greater15  Nmonthdrop_PER_p5y  \
# Stock_symbol
# 1101                                 False            4.000000
# 1102                                 False            4.000000
# 1103                                 False            2.333333
# 1104                                  True            4.000000
# 1108                                 False            0.000000
#
#               Nmonthdrop_PER_1y  Nmonthdrop_PER_2y  Nmonthdrop_PER_3y
# Stock_symbol
# 1101                  10.000000          16.666667          23.000000
# 1102                   9.666667          20.333333          24.333333
# 1103                   6.000000          13.000000          17.666667
# 1104                   6.333333           9.000000          15.333333
# 1108                   0.000000           0.000000           0.000000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 第一階段篩選 ##

# %%
filter1 = (df_basic['Nmonthgrowth_revenue_1ygreater6m'] == True)
filter2 = (df_basic['Nmonthgrowth_revenue_2ygreater15m'] == True)
filter3 = (df_basic['Nmonth_Dyield5_3year_greater15'] == True)
filter4 = (df_basic['Nmonth_Dyield5_2year_greater12'] == True)
filter5 = (df_basic['Nmonth_Dyield5_1year_greater9'] == True)

df_basic[(filter1 | filter2) & filter3 & filter4 & filter5].index
# Out:
# Index(['1101', '1210', '1229', '1233', '1464', '1615', '1773', '1817', '2006',
#        '2069', '2104', '2441', '3014', '4919', '5471', '6257', '8081', '8131',
#        '2356', '2376', '2397', '3005', '3515', '3706', '6277', '8114', '6136',
#        '2493', '3032', '3042', '4999', '6224', '2414', '3010', '3036', '3209',
#        '3528', '5434', '6189', '6281', '2480', '3029', '3130', '6112', '2433',
#        '3617', '1442', '2511', '2534', '2548', '2597', '5534', '6177', '2707',
#        '9943', '2812', '2820', '2838', '2850', '2851', '2855', '2867', '2884',
#        '2886', '2887', '2889', '2890', '5880', '6005', '8481', '9927', '9941'],
#       dtype='object', name='Stock_symbol')

# %% [markdown]
# ## 讀取財報資訊 ##

# %%
### Ignore 2812, 2820, 2838, 2850, 2851, 2855, 2867, 2884, 2886, 2887, 2889, 2890, 5880, 6005
company = 1101
try:
    df_fstatement = pd.read_csv('./Financial_statement/%d.csv' %(company),index_col=0)  

    df_fstatement.index = pd.to_datetime(df_fstatement.index, format='%Y-%m-%d').year

    ### Bug fix: pct_change() does not properly deal with negative values 
    df_fstatement['淨利成長率'] = (df_fstatement['繼續營業單位稅前淨利（淨損）'] - df_fstatement['繼續營業單位稅前淨利（淨損）'].shift())/abs(df_fstatement['繼續營業單位稅前淨利（淨損）'].shift()) * 100.
    df_fstatement['營收成長率'] = (df_fstatement['營業收入合計'] - df_fstatement['營業收入合計'].shift())/abs(df_fstatement['營業收入合計'].shift()) * 100.

    col_names = ['營業收入合計','營業毛利（毛損）','營業利益（損失）',
                 '繼續營業單位稅前淨利（淨損）','營業費用合計','本期淨利（淨損）',
                 '基本每股盈餘合計','本期現金及約當現金增加（減少）數','股東權益總額',
                 '資產總額','營業毛利率(%)','營業利益率(%)','純益率(%)','股東權益率(%)',
                 '總資產報酬率(%)','營收成長率','淨利成長率']

    ### 財務報表名詞中翻英: http://twstockcurves.blogspot.com/2014/08/blog-post.html
    col_names = ['Revenue','Gross Revenue','Operating Income',
                 'Income from Continuing Operation (before tax)','Operating Expenses','Net Income',
                 'Earnings Per Share','Net Increase (decrease) In Cash and Cash Equivalents','Total Equity',
                 'Total Assets','Profit Margin (%)','Operating Profit Margin (%)','Net Profit Margin (%)','Equity Ratio (%)',
                 'Return On Total Assets (%)','Revenue Growth Rate (%)','Net Profit Growth Rate (%)']


    for iname in range(len(col_names)):
        df_fstatement.rename(columns={df_fstatement.columns[iname]: col_names[iname]}, inplace=True)

    # (df_fstatement.style.background_gradient(cmap='Blues')
    #                     .highlight_null())
    # (df_fstatement.style.background_gradient(cmap='Blues')
    #                     .bar(subset=['Revenue Growth Rate (%)'],color=['indianred','limegreen'], align='mid')
    #                     .bar(subset=['Net Profit Growth Rate (%)'],color=['indianred','limegreen'], align='mid'))
    print ('Company %d \nNo error has occured, print dataframe in the next block' %(company))
    
except Exception as e:
    print('Company %d \nErrors have occured, please check if anything is wrong' %(company))
# Out:
# Company 1101
# No error has occured, print dataframe in the next block

# %%
(df_fstatement.style.background_gradient(cmap='Blues')
                        .bar(subset=['Revenue Growth Rate (%)'],color=['indianred','limegreen'], align='mid')
                        .bar(subset=['Net Profit Growth Rate (%)'],color=['indianred','limegreen'], align='mid'))
# Out:
# <style  type="text/css" >
#     #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col1 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col2 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col3 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col5 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col6 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col7 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col10 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col11 {
#             background-color:  #add0e6;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col12 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col13 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col14 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col15 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row0_col16 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col0 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col1 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col2 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col3 {
#             background-color:  #bad6eb;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col4 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col5 {
#             background-color:  #8fc2de;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col6 {
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col7 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col8 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col9 {
#             background-color:  #8fc2de;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col10 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col11 {
#             background-color:  #a4cce3;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col12 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col13 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col14 {
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col15 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.8%, limegreen 43.8%, limegreen 90.8%, transparent 90.8%);
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row1_col16 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.8%, limegreen 32.8%, limegreen 45.5%, transparent 45.5%);
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col0 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col1 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col2 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col3 {
#             background-color:  #a4cce3;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col4 {
#             background-color:  #539ecd;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col5 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col6 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col7 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col8 {
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col9 {
#             background-color:  #8fc2de;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col10 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col11 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col12 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col13 {
#             background-color:  #2676b8;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col14 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col15 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.8%, limegreen 43.8%, limegreen 68.1%, transparent 68.1%);
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row2_col16 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.8%, limegreen 32.8%, limegreen 38.7%, transparent 38.7%);
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row3_col0 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row3_col1 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35row3_col2 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_954f9fa8_2a21_11ea_bbb1_9801a7dc4b35

# %%
### 獲利性分析
### 1. ROE長期 > 15% （近1年數據 > 15% 與近5年平均ROE > 15%）
### ROE = Return On Equity  
###     = Equity Ratio (%) 股東權益報酬率、股東權益率
### 2. 淨利率(純益率 Net Profit Margin)長期 > 10% (近1年數據 > 10% , 近5年平均 > 10%)
print ('獲利性分析:')
print (' 近1年股東權益率(%) =', df_fstatement['Equity Ratio (%)'].iloc[-1:].values[0], 
       '; >15% ? =>', (df_fstatement['Equity Ratio (%)'].iloc[-1:].values[0] >= 15.))
print (' 近5年平均股東權益率(%) =',df_fstatement['Equity Ratio (%)'].iloc[-5:].mean(),
       '; >15% ? =>', (df_fstatement['Equity Ratio (%)'].iloc[-5:].mean() >= 15.))
print (' 近1年淨利率(%) =', df_fstatement['Net Profit Margin (%)'].iloc[-1:].values[0], 
       ' ; >15% ? =>',(df_fstatement['Net Profit Margin (%)'].iloc[-1:].values[0] >= 15.))
print (' 近5年平均淨利率(%) =',df_fstatement['Net Profit Margin (%)'].iloc[-5:].mean(),
       '; >15% ? =>', (df_fstatement['Net Profit Margin (%)'].iloc[-5:].mean() >= 15.))

### 安全性分析
### 3. 營業現金流對淨利比 > 50% （近一年數據 > 50%, 近5年平均 > 50%）
### 4. 自由現金流長期 > 0 （近一年數據 > 0, 近5年平均 > 0）
###    自由現金流在此取 “本期現金及約當現金增加（減少）數”
print ('安全性分析:')
print (' 近1年本期現金及約當現金增加（減少）數 (千元) =', df_fstatement['Net Increase (decrease) In Cash and Cash Equivalents'].iloc[-1:].values[0], 
       ' ; >0 ? =>',(df_fstatement['Net Increase (decrease) In Cash and Cash Equivalents'].iloc[-1:].values[0] >= 0.))
print (' 近5年平均本期現金及約當現金增加（減少）數 (千元) =',df_fstatement['Net Increase (decrease) In Cash and Cash Equivalents'].iloc[-5:].mean(),
       '; >0 ? =>', (df_fstatement['Net Increase (decrease) In Cash and Cash Equivalents'].iloc[-5:].mean() >= 15.))

print ('價值評估:')
print ('成長性分析:')
# df_fstatement['Equity Ratio (%)'].iloc[-5:].mean()
# Out:
# 獲利性分析:
#  近1年股東權益率(%) = 15.474974761304438 ; >15% ? => True
#  近5年平均股東權益率(%) = 10.200365573803092 ; >15% ? => False
#  近1年淨利率(%) = 24.515043597153593  ; >15% ? => True
#  近5年平均淨利率(%) = 15.72009161418615 ; >15% ? => True
# 安全性分析:
#  近1年本期現金及約當現金增加（減少）數 (千元) = 22176671.0  ; >0 ? => True
#  近5年平均本期現金及約當現金增加（減少）數 (千元) = 4559364.8 ; >0 ? => True
# 價值評估:
# 成長性分析:

# %% [markdown]
# ## 財報分析資料 ##

# %%
### 2012年後的財務分析資料無 “獲利能力-營業利益佔實收資本比率(%)” 此欄位

def fstatement_analysis(stock_symbol):
    df = pd.DataFrame()

    for y in range(2018,2008,-1):
        df_tmp = pd.read_csv('./Financial-analysis-report/%d.csv' %(y))
        # df_tmp['年份'] = y
        # df_tmp.set_index('年份',inplace=True, drop=True)
        df_tmp = df_tmp.loc[df_tmp['公司代號'] == stock_symbol]
        if y<=2012:
            df_tmp.rename(columns={'財務結構-長期資金佔固定資產比率(%)':'財務結構-長期資金佔不動產、廠房及設備比率(%)'}, inplace=True)
            df_tmp.rename(columns={'經營能力->應收款項收現日數':'經營能力-平均收現日數'}, inplace=True)
            df_tmp.rename(columns={'經營能力-固定資產週轉率(次)':'經營能力-不動產、廠房及設備週轉率(次)'}, inplace=True)
            df_tmp.rename(columns={'獲利能力-股東權益報酬率(%)':'獲利能力-權益報酬率(%)'}, inplace=True)

        df_tmp = df_tmp.T

        df['%d'%(y)] = df_tmp[df_tmp.columns[0]]

    df = df.T
    for col in df.columns:
        df[col] = pd.to_numeric(df[col], 'coerce')

    df.drop(['公司代號', '公司簡稱'], axis=1, inplace=True)
    df.rename(columns={'現金流量-現金再投<br>資比率(%)':'現金流量-現金再投資比率(%)'}, inplace=True)
    df.index = pd.to_datetime(df.index)  
    df.index = pd.to_datetime(df.index, format='%Y-%m-%d').year
    df = df.sort_index()
    
    return df

df_fstatement_analysis = fstatement_analysis(company)

(df_fstatement_analysis.style.background_gradient(cmap='Blues')
                    .highlight_null())
# Out:
# <style  type="text/css" >
#     #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col5 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col6 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col10 {
#             background-color:  #dfecf7;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col12 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col13 {
#             background-color:  #64a9d3;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col14 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col15 {
#             background-color:  #3181bd;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col16 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col17 {
#             background-color:  #539ecd;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row0_col18 {
#             background-color:  #a3cce3;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col0 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col1 {
#             background-color:  #08519c;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col2 {
#             background-color:  #7fb9da;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col3 {
#             background-color:  #9fcae1;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col4 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col5 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col6 {
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col7 {
#             background-color:  #3787c0;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col8 {
#             background-color:  #c4daee;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col9 {
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col10 {
#             background-color:  #eff6fc;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col11 {
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col12 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col13 {
#             background-color:  #a6cee4;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col14 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col15 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col16 {
#             background-color:  #d2e3f3;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col17 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row1_col18 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col0 {
#             background-color:  #c7dbef;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col1 {
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col4 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col5 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col6 {
#             background-color:  #2d7dbb;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col7 {
#             background-color:  #2676b8;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col8 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col9 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col10 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col11 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col12 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col13 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col14 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d9794e06_2a1a_11ea_bbb1_9801a7dc4b35row2_col15

# %% [markdown]
# ---
# ## 畫圖 ##

# %%
# company = '6277'
avg = 18 # 每個月平均取3筆資料 => 半年期間約18筆資料

fig, (ax1,ax2,ax3) = plt.subplots(3, figsize=(18, 9), 
                       sharex='col')

# fig = plt.figure(figsize=(18,9))
# ax1 = fig.add_subplot(311)
# ax2 = fig.add_subplot(312)
# ax3 = fig.add_subplot(313)

ax1.plot(df[company].index, df[company], label='Monthly Revenue', linewidth=3)
# ax1.bar(df[company].index, df[company], label='Monthly Revenue')
ax1.plot(df[company].index, df[company].rolling(avg).mean(), label='Moving average (%d months)' %(avg/3), linewidth=3)
# ax1.set_xlabel('Date',fontsize=21)
ax1.set_ylabel('Revenue', fontsize=26)
ax1.tick_params(axis='x', labelsize=23)
ax1.tick_params(axis='y', labelsize=23)
ax1.legend(loc='best',fontsize='xx-large')
ax1.set_title('Company: '+company,fontsize = 32)

ax2.plot(df_div_yield[company].index, df_div_yield[company], label='Dividend yield', linewidth=3)
ax2.plot(df_div_yield[company].index, df_div_yield[company].rolling(avg).mean(), label='Moving average (%d months)' %(avg/3), linewidth=3)
# ax2.set_xlabel('Date',fontsize=26)
ax2.set_ylabel('Dividend yield', fontsize=26)
ax2.tick_params(axis='x', labelsize=23)
ax2.tick_params(axis='y', labelsize=23)
ax2.legend(loc='best',fontsize='xx-large')

ax3.plot(df_PER[company].index, df_PER[company], label='PER (Price-to-Earning Ratio)', linewidth=3)
ax3.plot(df_PER[company].index, df_PER[company].rolling(avg).mean(), label='Moving average (%d months)' %(avg/3), linewidth=3)
ax3.set_xlabel('Date',fontsize=26)
ax3.set_ylabel('PER', fontsize=26)
ax3.tick_params(axis='x', labelsize=23)
ax3.tick_params(axis='y', labelsize=23)
ax3.legend(loc='best',fontsize='xx-large')

# ax3.plot(df_PBR[company].index, df_PBR[company], label='PBR (Price-Book Ratio)', linewidth=2.5)
# ax3.plot(df_PBR[company].index, df_PBR[company].rolling(avg).mean(), label='Moving average (%d months)' %(avg), linewidth=3)
# ax3.set_xlabel('Date',fontsize=26)
# ax3.set_ylabel('PBR', fontsize=26)
# ax3.tick_params(axis='x', labelsize=23)
# ax3.tick_params(axis='y', labelsize=23)
# ax3.legend(loc='best',fontsize='xx-large')
# ax3.set_title('PBR (Price-Book Ratio)',fontsize = 35)

plt.tight_layout()

# %%
fig = plt.figure(figsize=(18,10))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

fig.suptitle('Company code: '+company,fontsize = 32)

ax1.bar(df_fstatement.index, df_fstatement['Revenue'], label='Revenue',color='C0')
# ax1.set_ylabel('Revenue', fontsize=26)
ax1.tick_params(axis='x', labelsize=23)
ax1.tick_params(axis='y', labelsize=23)
ax1.legend(loc='best',fontsize='xx-large')
# ax1.set_title('Company: '+company,fontsize = 32)

ax2.bar(df_fstatement.index, df_fstatement['Gross Revenue'], label='Gross Revenue',color='C1')
# ax2.set_ylabel('Gross Revenue', fontsize=26)
ax2.tick_params(axis='x', labelsize=23)
ax2.tick_params(axis='y', labelsize=23)
ax2.legend(loc='best',fontsize='xx-large')

ax3.bar(df_fstatement.index, df_fstatement['Operating Income'], label='Operating Income',color='C2')
# ax3.set_ylabel('Operating Income', fontsize=26)
ax3.tick_params(axis='x', labelsize=23)
ax3.tick_params(axis='y', labelsize=23)
ax3.legend(loc='best',fontsize='xx-large')

ax4.bar(df_fstatement.index, df_fstatement['Income from Continuing Operation (before tax)'], 
         label='Income from Continuing Operation (before tax)',color='C3')
# ax4.set_ylabel('Income from Continuing Operation (before tax)', fontsize=26)
ax4.tick_params(axis='x', labelsize=23)
ax4.tick_params(axis='y', labelsize=23)
ax4.legend(loc='best',fontsize='xx-large')

ax5.bar(df_fstatement.index, df_fstatement['Operating Expenses'], label='Operating Expenses',color='C4')
# ax5.set_ylabel('Operating Expenses', fontsize=26)
ax5.tick_params(axis='x', labelsize=23)
ax5.tick_params(axis='y', labelsize=23)
ax5.legend(loc='best',fontsize='xx-large')

ax6.bar(df_fstatement.index, df_fstatement['Net Income'], label='Net Income',color='C5')
# ax6.set_ylabel('Net Income', fontsize=26)
ax6.tick_params(axis='x', labelsize=23)
ax6.tick_params(axis='y', labelsize=23)
ax6.legend(loc='best',fontsize='xx-large')

plt.tight_layout()
fig.subplots_adjust(top=0.9)

# df_fstatement['Profit Margin (%)'].plot(kind='bar')
# plt.ylabel('Profit Margin (%)')

# %%
fig = plt.figure(figsize=(24,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

fig.suptitle('Company code: '+company,fontsize = 32)

ax1.bar(df_fstatement.index, df_fstatement['Earnings Per Share'], label='Earnings Per Share',color='C0')
# ax1.set_ylabel('Revenue', fontsize=26)
ax1.tick_params(axis='x', labelsize=23)
ax1.tick_params(axis='y', labelsize=23)
ax1.legend(loc='best',fontsize='xx-large')
# ax1.set_title('Company: '+company,fontsize = 32)

ax2.bar(df_fstatement.index, df_fstatement['Net Increase (decrease) In Cash and Cash Equivalents'], 
        label='Net Increase (decrease) In Cash and Cash Equivalents',color='C1')
# ax2.set_ylabel('Gross Revenue', fontsize=26)
ax2.tick_params(axis='x', labelsize=23)
ax2.tick_params(axis='y', labelsize=23)
ax2.legend(loc='best',fontsize='xx-large')

ax3.bar(df_fstatement.index, df_fstatement['Total Equity'], label='Total Equity',color='C2')
# ax3.set_ylabel('Operating Income', fontsize=26)
ax3.tick_params(axis='x', labelsize=23)
ax3.tick_params(axis='y', labelsize=23)
ax3.legend(loc='best',fontsize='xx-large')

ax4.bar(df_fstatement.index, df_fstatement['Total Assets'], 
         label='Total Assets',color='C3')
# ax4.set_ylabel('Income from Continuing Operation (before tax)', fontsize=26)
ax4.tick_params(axis='x', labelsize=23)
ax4.tick_params(axis='y', labelsize=23)
ax4.legend(loc='best',fontsize='xx-large')

plt.tight_layout()
fig.subplots_adjust(top=0.9)

# df_fstatement['Profit Margin (%)'].plot(kind='bar')
# plt.ylabel('Profit Margin (%)')

# %%
fig = plt.figure(figsize=(18,14))
ax1 = fig.add_subplot(421)
ax2 = fig.add_subplot(422)
ax3 = fig.add_subplot(423)
ax4 = fig.add_subplot(424)
ax5 = fig.add_subplot(425)
ax6 = fig.add_subplot(426)
ax7 = fig.add_subplot(427)
# ax8 = fig.add_subplot(428)

fig.suptitle('Company code: '+company,fontsize = 32)

ax1.bar(df_fstatement.index, df_fstatement['Profit Margin (%)'], label='Profit Margin (%)',color='C0')
# ax1.set_ylabel('Revenue', fontsize=26)
ax1.tick_params(axis='x', labelsize=23)
ax1.tick_params(axis='y', labelsize=23)
ax1.legend(loc='best',fontsize='xx-large')
# ax1.set_title('Company: '+company,fontsize = 32)

ax2.bar(df_fstatement.index, df_fstatement['Operating Profit Margin (%)'], label='Operating Profit Margin (%)',color='C1')
# ax2.set_ylabel('Gross Revenue', fontsize=26)
ax2.tick_params(axis='x', labelsize=23)
ax2.tick_params(axis='y', labelsize=23)
ax2.legend(loc='best',fontsize='xx-large')

ax3.bar(df_fstatement.index, df_fstatement['Net Profit Margin (%)'], label='Net Profit Margin (%)',color='C2')
# ax3.set_ylabel('Operating Income', fontsize=26)
ax3.tick_params(axis='x', labelsize=23)
ax3.tick_params(axis='y', labelsize=23)
ax3.legend(loc='best',fontsize='xx-large')

ax4.bar(df_fstatement.index, df_fstatement['Equity Ratio (%)'], 
         label='Equity Ratio (%)',color='C3')
# ax4.set_ylabel('Income from Continuing Operation (before tax)', fontsize=26)
ax4.tick_params(axis='x', labelsize=23)
ax4.tick_params(axis='y', labelsize=23)
ax4.legend(loc='best',fontsize='xx-large')

ax5.bar(df_fstatement.index, df_fstatement['Return On Total Assets (%)'], label='Return On Total Assets (%)',color='C4')
# ax5.set_ylabel('Operating Expenses', fontsize=26)
ax5.tick_params(axis='x', labelsize=23)
ax5.tick_params(axis='y', labelsize=23)
ax5.legend(loc='best',fontsize='xx-large')

ax6.bar(df_fstatement.index, df_fstatement['Revenue Growth Rate (%)'], label='Revenue Growth Rate (%)',color='C5')
# ax6.set_ylabel('Net Income', fontsize=26)
ax6.tick_params(axis='x', labelsize=23)
ax6.tick_params(axis='y', labelsize=23)
ax6.legend(loc='best',fontsize='xx-large')

ax7.bar(df_fstatement.index, df_fstatement['Net Profit Growth Rate (%)'], label='Net Profit Growth Rate (%)',color='C6')
# ax6.set_ylabel('Net Income', fontsize=26)
ax7.tick_params(axis='x', labelsize=23)
ax7.tick_params(axis='y', labelsize=23)
ax7.legend(loc='best',fontsize='xx-large')

plt.tight_layout()
fig.subplots_adjust(top=0.9)

# df_fstatement['Profit Margin (%)'].plot(kind='bar')
# plt.ylabel('Profit Margin (%)')

# %% [markdown]
# ### Obsolete ###

# %%
### one simple way to visualize correlation matrix from dataframe
corr = df_fstatement.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col4 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col7 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col8 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col9 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col15 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row0_col16 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col2 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col3 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col4 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col5 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col8 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col9 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col10 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col11 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col12 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col13 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col14 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col15 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row1_col16 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col1 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col3 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col4 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col5 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col6 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col8 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col9 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col10 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col11 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col12 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col13 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col14 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col15 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row2_col16 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col1 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col2 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col4 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col5 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col6 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_97a4bf9e_26fd_11ea_9f00_9801a7dc4b35row3_col8 {
#             background-color:  #f7aa8c;
