# %%
import ROOT
import numpy as np
from array import array as ary
import math
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from matplotlib.dates import MonthLocator, DateFormatter
import datetime
# Out:
# Welcome to JupyROOT 6.16/00

# %%
df_2019 = pd.read_csv('merge-2019.csv',skipinitialspace=True)
df_2018 = pd.read_csv('merge-2018.csv',skipinitialspace=True) 
df_2017 = pd.read_csv('merge-2017.csv',skipinitialspace=True) 
df_2016 = pd.read_csv('merge-2016.csv',skipinitialspace=True) 
df_2015 = pd.read_csv('merge-2015.csv',skipinitialspace=True) 
df_2014 = pd.read_csv('merge-2014.csv',skipinitialspace=True) 
df_2013 = pd.read_csv('merge-2013.csv',skipinitialspace=True) 
df_2012 = pd.read_csv('merge-2012.csv',skipinitialspace=True) 
df_2011 = pd.read_csv('merge-2011.csv',skipinitialspace=True) 
df_2010 = pd.read_csv('merge-2010.csv',skipinitialspace=True) 

df_2019['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2019), freq='D')
# df_2019['Date'] = df_2019['StnPresMaxTime'].str.split(' ', 1).str[0]
# df_2019['Date'] = df_2019['Date'].str.replace('2019-', '')

df_2018['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2018), freq='D')
# df_2018['Date'] = df_2018['StnPresMaxTime'].str.split(' ', 1).str[0]
# df_2018['Date'] = df_2018['Date'].str.replace('2018-', '')

df_2017['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2017), freq='D')
df_2016['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2016), freq='D')
df_2015['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2015), freq='D')
df_2014['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2014), freq='D')
df_2013['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2013), freq='D')
df_2012['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2012), freq='D')
df_2011['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2011), freq='D')
df_2010['Date'] = pd.date_range(start='2018-01-01', periods=len(df_2010), freq='D')

df_2019=df_2019.rename(columns = {'T Min':'TMin'})
df_2018=df_2018.rename(columns = {'T Min':'TMin'})
df_2017=df_2017.rename(columns = {'T Min':'TMin'})
df_2016=df_2016.rename(columns = {'T Min':'TMin'})
df_2015=df_2015.rename(columns = {'T Min':'TMin'})
df_2014=df_2014.rename(columns = {'T Min':'TMin'})
df_2013=df_2013.rename(columns = {'T Min':'TMin'})
df_2012=df_2012.rename(columns = {'T Min':'TMin'})
df_2011=df_2011.rename(columns = {'T Min':'TMin'})
df_2010=df_2010.rename(columns = {'T Min':'TMin'})

df_2019=df_2019.rename(columns = {'T Max':'TMax'})
df_2018=df_2018.rename(columns = {'T Max':'TMax'})
df_2017=df_2017.rename(columns = {'T Max':'TMax'})
df_2016=df_2016.rename(columns = {'T Max':'TMax'})
df_2015=df_2015.rename(columns = {'T Max':'TMax'})
df_2014=df_2014.rename(columns = {'T Max':'TMax'})
df_2013=df_2013.rename(columns = {'T Max':'TMax'})
df_2012=df_2012.rename(columns = {'T Max':'TMax'})
df_2011=df_2011.rename(columns = {'T Max':'TMax'})
df_2010=df_2010.rename(columns = {'T Max':'TMax'})

df_2019 = df_2019.drop(df_2019[(df_2019.TMin == '...')].index)
df_2018 = df_2018.drop(df_2018[(df_2018.TMin == '...')].index)
df_2017 = df_2017.drop(df_2017[(df_2017.TMin == '...')].index)
df_2016 = df_2016.drop(df_2016[(df_2016.TMin == '...')].index)
df_2015 = df_2015.drop(df_2015[(df_2015.TMin == '...')].index)
df_2014 = df_2014.drop(df_2014[(df_2014.TMin == '...')].index)
df_2013 = df_2013.drop(df_2013[(df_2013.TMin == '...')].index)
df_2012 = df_2012.drop(df_2012[(df_2012.TMin == '...')].index)
df_2011 = df_2011.drop(df_2011[(df_2011.TMin == '...')].index)
df_2010 = df_2010.drop(df_2010[(df_2010.TMin == '...')].index)

df_2019 = df_2019.drop(df_2019[(df_2019.TMax == '...')].index)
df_2018 = df_2018.drop(df_2018[(df_2018.TMax == '...')].index)
df_2017 = df_2017.drop(df_2017[(df_2017.TMax == '...')].index)
df_2016 = df_2016.drop(df_2016[(df_2016.TMax == '...')].index)
df_2015 = df_2015.drop(df_2015[(df_2015.TMax == '...')].index)
df_2014 = df_2014.drop(df_2014[(df_2014.TMax == '...')].index)
df_2013 = df_2013.drop(df_2013[(df_2013.TMax == '...')].index)
df_2012 = df_2012.drop(df_2012[(df_2012.TMax == '...')].index)
df_2011 = df_2011.drop(df_2011[(df_2011.TMax == '...')].index)
df_2010 = df_2010.drop(df_2010[(df_2010.TMax == '...')].index)

# df_2019.TMin = df_2019.TMin.astype('float64',error='ignore') 
df_2019.TMin = df_2019.TMin.astype('float64') 
df_2018.TMin = df_2018.TMin.astype('float64',error='ignore') 
df_2017.TMin = df_2017.TMin.astype('float64',error='ignore') 
df_2016.TMin = df_2016.TMin.astype('float64',error='ignore') 
df_2015.TMin = df_2015.TMin.astype('float64',error='ignore') 
df_2014.TMin = df_2014.TMin.astype('float64',error='ignore') 
df_2013.TMin = df_2013.TMin.astype('float64',error='ignore') 
df_2012.TMin = df_2012.TMin.astype('float64',error='ignore') 
df_2011.TMin = df_2011.TMin.astype('float64',error='ignore') 
df_2010.TMin = df_2010.TMin.astype('float64',error='ignore') 

# df_2019.TMax = df_2019.TMax.astype('float64',error='ignore') 
df_2019.TMax = df_2019.TMax.astype('float64') 
df_2018.TMax = df_2018.TMax.astype('float64',error='ignore') 
df_2017.TMax = df_2017.TMax.astype('float64',error='ignore') 
df_2016.TMax = df_2016.TMax.astype('float64',error='ignore') 
df_2015.TMax = df_2015.TMax.astype('float64',error='ignore') 
df_2014.TMax = df_2014.TMax.astype('float64',error='ignore') 
df_2013.TMax = df_2013.TMax.astype('float64',error='ignore') 
df_2012.TMax = df_2012.TMax.astype('float64',error='ignore') 
df_2011.TMax = df_2011.TMax.astype('float64',error='ignore') 
df_2010.TMax = df_2010.TMax.astype('float64',error='ignore') 

df_2019.head()
# df_2019
# Out:
#    ObsTime  StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0        1   1025.5     ...     1027.8  2019-01-01 09:10     1023.7
# 1        2   1024.6     ...     1027.3  2019-01-02 09:08     1022.2
# 2        3   1023.9     ...     1025.8  2019-01-03 08:56     1022.5
# 3        4   1021.0     ...     1023.8  2019-01-04 00:01     1018.0
# 4        5   1018.4     ...     1019.8  2019-01-05 20:22     1016.7
#
#      StnPresMinTime  Temperature  TMax        T Max Time  ...  PrecpHrMaxTime  \
# 0  2019-01-01 14:31         18.6  19.7  2019-01-01 11:18  ...             ...
# 1  2019-01-02 14:26         18.0  19.6  2019-01-02 13:22  ...             ...
# 2  2019-01-03 03:13         19.4  21.0  2019-01-03 22:05  ...             ...
# 3  2019-01-04 15:06         21.0  24.4  2019-01-04 14:41  ...             ...
# 4  2019-01-05 13:01         21.0  25.8  2019-01-05 10:48  ...             ...
#
#   SunShine SunShineRate GloblRad VisbMean EvapA  UVI Max UVI Max Time  \
# ...

# %%
var='Temperature'
fig, ax = plt.subplots(figsize=(30,5))

# Colormap reference: https://matplotlib.org/1.2.1/examples/pylab_examples/show_colormaps.html
# colormap = plt.cm.YlGnBu
colormap = plt.cm.get_cmap('YlGnBu_r') # reverse the colormap --> 'YlGnBu_r'
plt.gca().set_prop_cycle(plt.cycler('color', colormap(np.linspace(0, 1, 10))))

Temp_2019 = df_2019.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2018 = df_2018.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2017 = df_2017.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2016 = df_2016.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2015 = df_2015.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2014 = df_2014.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2013 = df_2013.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2012 = df_2012.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2011 = df_2011.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
Temp_2010 = df_2010.plot(ax=ax, kind = 'line', x='Date', y=var, linewidth=3)
plt.legend(('2019','2018','2017','2016','2015','2014','2013','2012','2011','2010'),fontsize='x-large', ncol=5)

plt.xlabel('Date', fontsize=20)
plt.ylabel('Temprature ($^\circ$C)', fontsize=20)
plt.tick_params(labelsize=15, direction='in', axis='both' ,which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

# ax.set_xlim([datetime.date(2018, 9, 1), datetime.date(2018, 11, 1)])

ax.xaxis.set_major_formatter(NullFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.xaxis.set_major_locator(MonthLocator())
ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('%b %d'))

plt.title('Average temperature', loc='left', fontsize='xx-large')
plt.tight_layout()

plt.savefig('./Temp-comparison.png')
plt.savefig('./Temp-comparison.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(30,5))

# Colormap reference: https://matplotlib.org/1.2.1/examples/pylab_examples/show_colormaps.html
# colormap = plt.cm.YlGnBu
colormap = plt.cm.get_cmap('YlGnBu_r') # reverse the colormap --> 'YlGnBu_r'
plt.gca().set_prop_cycle(plt.cycler('color', colormap(np.linspace(0, 1, 10))))

TMin_2019 = df_2019.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2018 = df_2018.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2017 = df_2017.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2016 = df_2016.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2015 = df_2015.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2014 = df_2014.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2013 = df_2013.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2012 = df_2012.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2011 = df_2011.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
TMin_2010 = df_2010.plot(ax=ax, kind = 'line', x='Date', y='TMin', linewidth=3)
plt.legend(('2019','2018','2017','2016','2015','2014','2013','2012','2011','2010'),fontsize='x-large', ncol=5)

plt.xlabel('Date', fontsize=20)
plt.ylabel('Temprature ($^\circ$C)', fontsize=20)
plt.tick_params(labelsize=15, direction='in', axis='both' ,which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

# ax.set_xlim([datetime.date(2018, 9, 1), datetime.date(2018, 11, 1)])

ax.xaxis.set_major_formatter(NullFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.xaxis.set_major_locator(MonthLocator())
ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('%b %d'))

plt.title('Minimum temperature', loc='left', fontsize='xx-large')
plt.tight_layout()
plt.savefig('./Temp-minimum-comparison.png')
plt.savefig('./Temp-minimum-comparison.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(30,5))

# Colormap reference: https://matplotlib.org/1.2.1/examples/pylab_examples/show_colormaps.html
# colormap = plt.cm.YlGnBu
colormap = plt.cm.get_cmap('YlGnBu_r') # reverse the colormap --> 'YlGnBu_r'
plt.gca().set_prop_cycle(plt.cycler('color', colormap(np.linspace(0, 1, 10))))

TMin_2019 = df_2019.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2018 = df_2018.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2017 = df_2017.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2016 = df_2016.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2015 = df_2015.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2014 = df_2014.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2013 = df_2013.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2012 = df_2012.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2011 = df_2011.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
TMin_2010 = df_2010.plot(ax=ax, kind = 'line', x='Date', y='TMax', linewidth=3)
plt.legend(('2019','2018','2017','2016','2015','2014','2013','2012','2011','2010'),fontsize='x-large', ncol=5)

plt.xlabel('Date', fontsize=20)
plt.ylabel('Temprature ($^\circ$C)', fontsize=20)
plt.tick_params(labelsize=15, direction='in', axis='both' ,which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

# ax.set_xlim([datetime.date(2018, 9, 1), datetime.date(2018, 11, 1)])

ax.xaxis.set_major_formatter(NullFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.xaxis.set_major_locator(MonthLocator())
ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('%b %d'))

plt.title('Maximum temperature', loc='left', fontsize='xx-large')
plt.tight_layout()
plt.savefig('./Temp-maximum-comparison.png')
plt.savefig('./Temp-maximum-comparison.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))

# Colormap reference: https://matplotlib.org/1.2.1/examples/pylab_examples/show_colormaps.html
# colormap = plt.cm.YlGnBu
colormap = plt.cm.get_cmap('YlGnBu_r') # reverse the colormap --> 'YlGnBu_r'
plt.gca().set_prop_cycle(plt.cycler('color', colormap(np.linspace(0, 1, 4))))

ax.plot(df_2019.Date, df_2019.Temperature, linewidth=3)
ax.plot(df_2018.Date, df_2018.Temperature, linewidth=3)
# ax.plot(df_2017.Date, df_2017.Temperature, linewidth=3)
# ax.plot(df_2016.Date, df_2016.Temperature, linewidth=3)
ax.fill_between(df_2019.Date, df_2019.TMin, df_2019.TMax, alpha=0.35)
ax.fill_between(df_2018.Date, df_2018.TMin, df_2018.TMax, alpha=0.35)
# ax.fill_between(df_2017.Date, df_2017.TMin, df_2017.TMax, alpha=0.35)
# ax.fill_between(df_2016.Date, df_2016.TMin, df_2016.TMax, alpha=0.35)

# plt.legend(('2019 (average)','2018 (average)','2017 (average)','2016 (average)','2019 (range)','2018 (range)','2017 (range)','2016 (range)'),fontsize='x-large', ncol=2)
plt.legend(('2019 (average)','2018 (average)','2019 (range)','2018 (range)'),fontsize='x-large', ncol=2)

plt.xlabel('Date', fontsize=20)
plt.ylabel('Temprature ($^\circ$C)', fontsize=20)
plt.tick_params(labelsize=15, direction='in', axis='both' ,which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

ax.set_xlim([datetime.date(2018, 8, 1), datetime.date(2018, 12, 31)])
# ax.set_xlim([datetime.date(2018, 1, 1), datetime.date(2018, 12, 31)])

ax.xaxis.set_major_formatter(NullFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.xaxis.set_major_locator(MonthLocator())
ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('%b %d'))

plt.title('Temperature (Jian, Hualien)', loc='left', fontsize='xx-large')
plt.tight_layout()

plt.savefig('./Temp-comparison-MaxMin-20182019-AugToDec.png')
plt.savefig('./Temp-comparison-MaxMin-20182019-AugToDec.pdf')
plt.show()
